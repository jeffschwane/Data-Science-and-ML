# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


# classifier we will use
from sklearn.tree import DecisionTreeClassifier

# model selection bits
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedShuffleSplit, StratifiedKFold
from sklearn.model_selection import learning_curve, validation_curve

# evaluation
from sklearn.metrics import f1_score

# plotting
from plotting import plot_learning_curve, plot_validation_curve

# %% [markdown]
# # Detecting Spam with Decision Trees
#
# In the last assignment we worked with the spam database. We are going to do the same thing in this assignment and we will practice with the correct tools this time around.

# %%
## we are going to hardcode the column names, because this just makes it a little easier to use pandas.

names = ['word_freq_make:        ',
'word_freq_address:     ',
'word_freq_all:         ',
'word_freq_3d:          ',
'word_freq_our:         ',
'word_freq_over:        ',
'word_freq_remove:      ',
'word_freq_internet:    ',
'word_freq_order:       ',
'word_freq_mail:        ',
'word_freq_receive:     ',
'word_freq_will:        ',
'word_freq_people:      ',
'word_freq_report:      ',
'word_freq_addresses:   ',
'word_freq_free:        ',
'word_freq_business:    ',
'word_freq_email:       ',
'word_freq_you:         ',
'word_freq_credit:      ',
'word_freq_your:        ',
'word_freq_font:        ',
'word_freq_000:         ',
'word_freq_money:       ',
'word_freq_hp:          ',
'word_freq_hpl:         ',
'word_freq_george:      ',
'word_freq_650:         ',
'word_freq_lab:         ',
'word_freq_labs:        ',
'word_freq_telnet:      ',
'word_freq_857:         ',
'word_freq_data:        ',
'word_freq_415:         ',
'word_freq_85:          ',
'word_freq_technology:  ',
'word_freq_1999:        ',
'word_freq_parts:       ',
'word_freq_pm:          ',
'word_freq_direct:      ',
'word_freq_cs:          ',
'word_freq_meeting:     ',
'word_freq_original:    ',
'word_freq_project:     ',
'word_freq_re:          ',
'word_freq_edu:         ',
'word_freq_table:       ',
'word_freq_conference:  ',
'char_freq_;:           ',
'char_freq_(:           ',
'char_freq_[:           ',
'char_freq_!:           ',
'char_freq_$:           ',
'char_freq_#:           ',
'capital_run_length_average',
'capital_run_length_longest',
'capital_run_length_total: ',
'label']

# %%
## Load in the dataset here 

data = pd.read_csv('spambase/spambase.csv', names = names)
X = data.drop('label', axis = 1)
y = data.label

# %%
# this time we will keep a bit more data for training and validation.
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8, stratify = y)

# %% [markdown]
# ## 1. Evaluate your classifier using 5 fold cross validation.
#
# Do you see any variance in different runs?
# Why do you think this is happening?

# %%
# create a default decision tree model
clf = DecisionTreeClassifier()

# create a stratifiedKfold cv object -- we want stratified to keep the class balance across folds
cv = StratifiedKFold(n_splits = 5)  # set it for 5 folds

# get the scores back using the helper function, make sure to pass a scoring function string - otherwise you default to accuracy
scores = cross_val_score(clf, X_train, y_train, scoring='f1', cv=cv)

# %%
print(scores)
# Out:
# [0.89115646 0.90034364 0.90387858 0.89619377 0.89583333]

# %%
print(scores.mean())
# Out:
# 0.8974811587260421

# %% [markdown]
# ### Looking for variance in the runs
#
# How much do the runs change over time? Let's run a for-loop and check.  In fact, that's exactly what shuffle split will do for us, so we can just run 100 iterations with 25% held out as validations - this will mimick 5-fold CV in the long run.

# %%
sss_split = StratifiedShuffleSplit(n_splits = 100, test_size=.2) # fill in the params
scores_sss = cross_val_score(clf, X_train, y_train, scoring='f1', cv=sss_split)

# %%
# print at your own risk!
print (scores_sss)
# Out:
# [0.89156627 0.87837838 0.88773748 0.86386555 0.88013699 0.88851351
#  0.8957265  0.89966555 0.88468158 0.8718802  0.87285223 0.87118644
#  0.88547009 0.90136054 0.89       0.85813149 0.88123924 0.8626087
#  0.8650519  0.87873462 0.89261745 0.87521368 0.89690722 0.89001692
#  0.89193825 0.91349481 0.8605852  0.88186356 0.90689655 0.89310345
#  0.87563884 0.88235294 0.88468158 0.87719298 0.89189189 0.9109589
#  0.89447236 0.89411765 0.89845095 0.88616462 0.86910995 0.88586031
#  0.87606112 0.88067227 0.88333333 0.87456446 0.85908319 0.87091222
#  0.9025641  0.88965517 0.88194444 0.89225589 0.86643836 0.89001692
#  0.8836425  0.87520799 0.89879931 0.90401396 0.88586031 0.87713311
#  0.8989547  0.88026981 0.89761092 0.91764706 0.9100346  0.85813149
#  0.89230769 0.86655113 0.8907563  0.89041096 0.86458333 0.89376054
#  0.88333333 0.89438944 0.87847222 0.88107203 0.88       0.87648054
#  0.88275862 0.89003436 0.88183422 0.875      0.87863248 0.88388215
#  0.89225589 0.85470085 0.89830508 0.87223169 0.88812392 0.89930556
#  0.88547009 0.87700535 0.9001692  0.88663283 0.86987522 0.8991453
#  0.89115646 0.86201022 0.8877551  0.87973641]

# %%
scores_sss.mean()
# Out:
# 0.8844526307690473

# %% [markdown]
# ### Plotting a histogram of the runs
#
# So we want to look for variance or variation in the runs. It's not easy to just look at a large list of scores and get any idea, so I will plot a histogram which should show us the distribution of results.

# %%
plt.figure(figsize=(10,6))
sns.distplot(scores_sss, bins=10);  # go ahead and try different bins

# %% [markdown]
# ### What does the histogram tell you?
#
# What is the mean of the our model? What kind of variation can we expect?
#
# #### Your answer below :

# %% [markdown]
# The mean of the model is 0.88, and it varies from about 0.86 to 0.92 with a more or less gaussian distribution.

# %% [markdown]
# ## 2. Tune your models hyper-parameters with Gridsearch
#
# Choose at least **3** parameters with **3** values each (total **9**) to search over
# When you create your GridSearchCV object make sure to set the following
#
# 1. cv object - which CV do you want to use? This will be run for every experiment, so if you do 100 sss, then you get 100 experiments for every parameter setting! This will add up fast. So make sure to choose something reasonable.
# 2. scoring parameter - never forget this!
#
# If you don't set the above, GridSearchCV will default to kfold=5 for the CV and accuracy for the scoring parameter.  kfold=5 isn't the worst (stratifiedkfold is better for us), but accuracy is really wrong for this dataset since it's unbalanced and a spam dataset.

# %%
# you need to setup a paramgrid.  I will give you one example

param_grid = {'max_depth':[2,10,20,30], 'min_samples_leaf':[2, 5, 10] ,'min_samples_split':[10,20,100]}

# %%
## make a gridsearch object and pass all the needed parameters.
grid = GridSearchCV(clf, param_grid, scoring='f1', cv=cv)

# %%
# fit your grid-search! - it's an estimator so you fit it like a normal model.
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [2, 10, 20, 30],
#                          'min_samples_leaf': [2, 5, 10],
#                          'min_samples_split': [10, 20, 100]},
#              scoring='f1')

# %%
grid.get_params().keys()
# Out:
# dict_keys(['cv', 'error_score', 'estimator__ccp_alpha', 'estimator__class_weight', 'estimator__criterion', 'estimator__max_depth', 'estimator__max_features', 'estimator__max_leaf_nodes', 'estimator__min_impurity_decrease', 'estimator__min_impurity_split', 'estimator__min_samples_leaf', 'estimator__min_samples_split', 'estimator__min_weight_fraction_leaf', 'estimator__presort', 'estimator__random_state', 'estimator__splitter', 'estimator', 'iid', 'n_jobs', 'param_grid', 'pre_dispatch', 'refit', 'return_train_score', 'scoring', 'verbose'])

# %% [markdown]
# ## 2.1: Gridsearch Results
#
# 1. What are the final parameters that were best?  (grid.best_params_)
# 2. What was your models best score? (grid.best_score_)
# 3. You can also print out the best estimator with grid.best_estimator_
# 4. Go ahead and put your grid results into a dataframe.

# %%
grid.best_params_
# Out:
# {'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 10}

# %%
grid.best_score_
# Out:
# 0.9001725817445239

# %%
grid.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=30, min_samples_leaf=2, min_samples_split=10)

# %%
results = pd.DataFrame(grid.cv_results_)

# %%
results.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.014760      0.002981         0.004190        0.002033
# 1       0.011558      0.000487         0.002793        0.000400
# 2       0.011375      0.000510         0.002196        0.000399
# 3       0.012766      0.003591         0.002587        0.000482
# 4       0.010962      0.000012         0.002801        0.000403
#
#   param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0               2                      2                      10
# 1               2                      2                      20
# 2               2                      2                     100
# 3               2                      5                      10
# 4               2                      5                      20
#
#                                               params  split0_test_score  \
# 0  {'max_depth': 2, 'min_samples_leaf': 2, 'min_s...           0.787645
# 1  {'max_depth': 2, 'min_samples_leaf': 2, 'min_s...           0.787645
# 2  {'max_depth': 2, 'min_samples_leaf': 2, 'min_s...           0.787645
# 3  {'max_depth': 2, 'min_samples_leaf': 5, 'min_s...           0.787645
# 4  {'max_depth': 2, 'min_samples_leaf': 5, 'min_s...           0.787645
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.786822           0.802218           0.788462           0.791252
# 1           0.786822           0.802218           0.788462           0.791252
# 2           0.786822           0.802218           0.788462           0.791252
# 3           0.786822           0.802218           0.788462           0.791252
# 4           0.786822           0.802218           0.788462           0.791252
#
#    mean_test_score  std_test_score  rank_test_score
# 0          0.79128        0.005669               28
# 1          0.79128        0.005669               28
# 2          0.79128        0.005669               28
# 3          0.79128        0.005669               28
# 4          0.79128        0.005669               28

# %%
results.shape
# Out:
# (36, 16)

# %% [markdown]
# ## 3.  Randomized Search
#
# #### Step 1, Distributions
# In order to do randomized search we need to draw from a distribution.  This can be a bit confusing so I will first just plot some distributions for you, then it will be pretty clear which ones we want to draw from.
#
# For decision trees most of the parameters we want to try out are integers. `min_samples_split`, `max_depth`, etc they are all integer numbers. So I will focus on distributions which draw integers

# %%
import scipy

# %%
sns.distplot(scipy.stats.norm(5, scale=2).rvs(1000));

# %% [markdown]
# This is the gaussian or normal distribution.  In fact, we can't use it because it doesn't draw integers-- but I just wanted to show it to you! Well I suppose we could use it and then convert the output to integers.

# %%
numbers = scipy.stats.norm(5, scale=2).rvs(1000)
sns.distplot(numbers.astype(int));

# %% [markdown]
# So we can use the gaussian and convert to integers, or we can draw from a uniform random distribution. That's plotted below. It basically says "pick a random number! Any random number!"

# %%
sns.distplot(scipy.stats.randint(0,50).rvs(1000));

# %% [markdown]
# So we need to choose a distribution for our grid-search. Based on what area we want to search we can choose uniform or int-converted gaussian. If we choose guassian we can "target" it by adjusting the mean and std, similarly we can set the range on the uniform distribution (the low and high ends).  You can decide what you want for your distribution. I will give you on example of how to setup the paramter grid for randomized search below.

# %%
rand_params = {'max_depth': scipy.stats.randint(2,100),
               'min_samples_leaf': scipy.stats.randint(2,100),
               'min_samples_split': scipy.stats.randint(5,100)}

## note that we don't say "how many" samples to draw in the param grid.
## We will do that below when we create the RandomizedSearchCV object

# %% [markdown]
# Note that we don't say "how many" samples to draw in the param grid. We will do that below when we create the RandomizedSearchCV object. You need to set the following
# * estimator
# * params
# * n_iters (this decides how many times to sample from the distribution per setting)
# * scoring
# * cv

# %%
rand_search = RandomizedSearchCV(clf, rand_params, scoring='f1', n_jobs=-1, cv=cv)

# %%
rand_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#                    estimator=DecisionTreeClassifier(), n_jobs=-1,
#                    param_distributions={'max_depth': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000027EAB7838B0>,
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000027EAB76A0A0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000027EAB7A7160>},
#                    scoring='f1')

# %%
rand_search.best_params_
# Out:
# {'max_depth': 85, 'min_samples_leaf': 7, 'min_samples_split': 55}

# %%
rand_search.best_score_
# Out:
# 0.8905941461387494

# %%
rand_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=85, min_samples_leaf=7, min_samples_split=55)

# %% [markdown]
# ### Did you find different best parameters?
# Which method do you like more?
# What method do you think got better results?
# Why? Why not?

# %% [markdown]
# ### You answers here

# %% [markdown]
# Ironically gridsearch got better results with a better f1 score despite randomized search going much deeper and probably overfitting. I'm not sure why that is the case, I would have though randomized search would do better, since it should search over a larger space.

# %% [markdown]
# ## 4. Validate your classifier using
#
# 1. Learning Curve
# 2. Validation Curves (complexity graph)
#
# Please plot at least 3 different validation curves for 3 different hyper-parameters than you can tune.
#
# You can (and should) use the imported functions `plot_validation_curve` and `plot_learning_curve`. These functions are originally found on sklearn's site but I did modify them slightly for our use. You can check out the full code in plotting.py, which also contains links to the original source code.

# %%
plot_validation_curve(rand_search.best_estimator_, X_train, y_train, cv=cv,
                      scoring='f1', param_name='max_depth',param_range=np.arange(1,100,5))
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x27eabb34d90>)

# %% [markdown]
# The curves very quickly flatten out once the model gets too complex, so let's zoom-in.

# %%
plot_validation_curve(rand_search.best_estimator_, X_train, y_train, cv=cv,
                      scoring='f1', param_name='max_depth',param_range=np.arange(1,12,1))
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x27eacd4a520>)

# %% [markdown]
# It is expected that training will always be better than cross-validation. After a max depth of about 6, it doesn't improve.

# %%
plot_validation_curve(rand_search.best_estimator_, X_train, y_train, cv=cv, scoring='f1', param_name='min_samples_leaf',param_range=np.arange(1,100,5))
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x27eabb66dc0>)

# %% [markdown]
# The cross validation score gets better until min samples in the leaf are between 5-10. Let's zoom-in.

# %%
plot_validation_curve(rand_search.best_estimator_, X_train, y_train, cv=cv, scoring='f1', param_name='min_samples_leaf',param_range=np.arange(1,20,1))
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x27eace72b80>)

# %% [markdown]
# It looks like the best fit is around min leaf samples = 8.

# %%
plot_validation_curve(rand_search.best_estimator_, X_train, y_train, cv=cv, scoring='f1', param_name='min_samples_split',param_range=np.arange(5,100,5))
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x27eabc57fd0>)

# %% [markdown]
# It looks like the best fit is around 50.

# %%
plot_learning_curve(clf, X_train, y_train, cv=cv, train_sizes=np.linspace(.1,1.0,10), scoring='f1')
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x27eaa207e80>)

# %% [markdown]
# This gap, plus the training score staying at 1 indicates that this particular model is overfit.

# %%
plot_learning_curve(rand_search.best_estimator_, X_train, y_train, cv=cv, train_sizes=np.linspace(.1,1.0,10), scoring='f1')
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x27eab7b9370>)

# %% [markdown]
# This is a pretty good fit, since the cross-validation score approaches the training score as we get more data.

# %% [markdown]
# ## 5. Choose your best parameters:
#
# Keep in mind that the random-search and grid-search will always maximize the validation score, even if it's in the area of overfitting. Looking at the validation curves you created, what you do think are the best parameter values?
#
# Now create a tree model with this and fit it.

# %% [markdown]
# Max Depth: 6, Min Samples Leaf: 8, Min Samples Split: 50

# %%
mydtc = DecisionTreeClassifier(max_depth=6,min_samples_leaf=8,min_samples_split=50)

# %%
mydtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, min_samples_leaf=8, min_samples_split=50)

# %% [markdown]
# ## 6. Looking at Feature Importances
#
# Decision trees have a nice property that they can automatically sort your features by importance. This just naturally falls out from the gini coefficient or the information gain ratio (whichever one you used).  Therefore we can run a little code and actually see which features our model found to be the most important.
#
#
# The code from Chris Albon below will help you do this, go ahead and run it.

# %%
## https://chrisalbon.com/machine_learning/trees_and_forests/feature_importance/

importances = mydtc.feature_importances_

indices = np.argsort(importances)[::-1]

# rearrange feature names so they match the sorted feature names
# I have my original names list of feature names, which corresponds to the features in the tree.
f_names = [names[i] for i in indices]

#create my plot
fig, axes = plt.subplots(figsize=(20,5))
axes.set_title("Feature Importances")
axes.bar(range(X_train.shape[1]), importances[indices])

# Add feature names as x-axis labels
axes.set_xticks(range(X.shape[1]));
axes.set_xticklabels(f_names, rotation=45, ha='right');

# %% [markdown]
# What is the most important feature that your model found? Does this surprise you, why or why not?
#
# #### Your Answers:

# %% [markdown]
# My model found the most important feature to be the character frequency of "!", followed by the run length of capital letters, neither of which surprises me for spam. :)

# %% [markdown]
# ## 6. Test your data.
#
# Retrain your model using all the training data and using the hyper parameters you think are best.
# Then go ahead and test your model with the test data. Evaluate your model by testing on the test set. How did you do? What is your performance?
#
# As always, ask yourself the question "If I was doing this professionally for a company, what other questions would I want answered?" Is this model ready to go??

# %%
test_predictions = mydtc.predict(X_test)

# %%
test_f1 = f1_score(y_test, test_predictions)
print(test_f1)
# Out:
# 0.8591749644381224

# %% [markdown]
# I got an F1 score of 0.86, which is ok I guess? I'm not really sure how to compare. I think I'd want to test my model with different email sets and more data and see how it performs before it was ready to go.
